# %%
import pandas as pd
import glob
import os
# Out:
# c:\users\abala\appdata\local\programs\python\python38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\abala\appdata\local\programs\python\python38\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\users\abala\appdata\local\programs\python\python38\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
def isVaxRelated(tag):
    tag = str(tag)
    global ChosenTags
    if 'vax' in tag or 'vacc' in tag:
        ChosenTags.add(tag)
        return True
    else:
        return False

# %%
important_cols = ["Tweet_ID", "Hastag"]
path = "D:\\CovidTweets\\COVID19_Tweets_Dataset_2021\\Summary_Hashtag"
outputFile = 'Hashtag-vax.csv'
ChosenTags = set()

totDf = pd.DataFrame()
for file in os.listdir(path):
    dfDets = pd.DataFrame()
    dfSent = pd.DataFrame()
    d = os.path.join(path, file)
    if os.path.isdir(d):
        print(file)
        print(len(totDf))
        all_files = glob.glob(os.path.join(d, "*.csv"))
        for f in all_files:
            if(os.path.exists(f)):
                dfDets = pd.read_csv(f)
                dfDets['Hastag'] = dfDets['Hastag'].str.lower()
                dfDets = dfDets[dfDets["Hastag"].apply(isVaxRelated)]
                totDf = pd.concat([totDf,dfDets], ignore_index = True)
totDf.to_csv(outputFile,index=False)
# Out:
# 2021_01
# 0
# 2021_02
# 1195101
# 2021_03
# 1978264
# 2021_04
# 3053097
# 2021_05
# 4369166
# 2021_06
# 5739205
# 2021_07
# 6978194
# 2021_08
# 8379046
# 2021_09
# 9915515
# 2021_10
# 11097289
# 2021_11
# 11803853
# 2021_12
# 12724127

# %%
rowsPerFile = 100 ## if not given(-1), use the whole file rather than a sample
important_cols = ["Tweet_ID", "Date Created", "Sentiment_Label", "Logits_Neutral", "Logits_Positive", "Logits_Negative"]
path = "D:\\CovidTweets\\COVID19_Tweets_Dataset_2021\\Summary_Details"
outputFile = 'peaktweets-Vax.csv'
hashtags = pd.read_csv("Hashtag-vax.csv")
tagSet = set(hashtags['Tweet_ID'])

totDf = pd.DataFrame()
for file in os.listdir(path):
    dfDets = pd.DataFrame()
    dfSent = pd.DataFrame()
    d = os.path.join(path, file)
    if os.path.isdir(d):
        print(file)
        print(len(totDf))
        all_files = glob.glob(os.path.join(d, "*.csv"))
        for f in all_files:
            nuF = f.replace('Details','Sentiment')
            if(os.path.exists(nuF)):
                dfDets = pd.read_csv(f)
                dfDets = dfDets[dfDets['Tweet_ID'].isin(tagSet)]
                if len(dfDets[dfDets["Language"] == 'en']) > rowsPerFile:
                    rowsToTake = rowsPerFile
                else:
                    rowsToTake = len(dfDets[dfDets["Language"] == 'en']) 
                if rowsPerFile != -1:
                    dfDets = dfDets[dfDets["Language"] == 'en'].sample(n=rowsToTake, random_state=42)
                dfSent = pd.read_csv(nuF)
                totDf = pd.concat([totDf,pd.merge(dfDets,dfSent, how = 'inner',on='Tweet_ID')[important_cols]], ignore_index = True)
totDf.to_csv(outputFile,index=False)
# Out:
# 2021_01
# 0
# c:\users\abala\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3139: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 2021_02
# 72600
# 2021_03
# 138073
# 2021_04
# 207954
# 2021_05
# 279354
# 2021_06
# 350556
# 2021_07
# 421856
# 2021_08
# 490456
# 2021_09
# 562656
# 2021_10
# 633856
# 2021_11
# 701256
# 2021_12
# 773256

# %%
justIDf = pd.DataFrame()
justIDf['TweetId'] = totDf['Tweet_ID']
justIDf.to_csv('justID.csv', index = False)
# Out:
# {'#dontcareanymorevaxxersarebullies',
#  '#vaccinatedandwearingamask',
#  '#novaccineboosters',
#  '#postvacc',
#  '#euvaccineexportbancanada',
#  '#yougetavaccine',
#  '#largestvaccinationdr',
#  '#experminetalvaccine',
#  '#vaccineoc',
#  '#vaccinatirplicht',
#  '#aftervaxnomax',
#  '#covidvaccine⏬',
#  '#westfieldvaccinationcentre',
#  '#betterthanvaccine',
#  '#nevertoolaterogetvaccinated',
#  '#uttarpradeshvaccinationlatestnews',
#  '#largestvaccinationotpdrive',
#  '#vaxecutions',
#  '#covidvaccineclinic',
#  '#morevaccinesforgaza',
#  '#thoughsafevaccineshere',
#  '#smsaftervaccines',
#  '#enhancedvaccinepassport',
#  '#lapvaccine',
#  '#whenwilltheothervaccinesyouboughtarrive',
#  '#vaccinatetosavesouthaf',
#  '#pahelevaccinefirexam',
#  '#axethevaxx',
#  '#anilvijvaccine',
#  '#vaccineandtestmandate',
#  '#disonestidelvaccino',
#  '#my1stdosecovid19vaccine',
#  '#originalvaccine',
#  '#vaccîn',
#  '#vaxalonewillnotwork',
#  '#selfvaccinate',
#  '#bankofferforvaccination',
#  '#vaccinationcancerpatients',
#  '#unvaxxedareasshats',
#  '#vaccinazioneavvocati',
#  '#vaccinatecoyote',
#  '#vaccinatpm',
#  '#mandatorywelfarevaccine',
#  '#covidvaccinesaretherapeutic',
#  '#vaccinationslot',
#  '#arrestcovid19viccovid19nswnovaccinepassport',
#  '#trumpwassecretlyvaccinated',
#  '#lesprovaxsontfous',
#  '#covavax',
#  '#vaccinmoncul',
#  '#vaccineforcoronapatients',
#  '#resistforcedvaccination',
#  '#bharatserumsandvaccines',
#  '#antivaxxers666',
#  '#vaccinationsafeeffectiv',
#  '#covid19vaccineade',
#  '#vax❓we❓hospital',
#  '#vaccineendedpolio',
#  '#statevaccinations',
#  '#projettiffanyvaccinationcovidvaccin',
#  '#antivaxxershe',
#  '#vaxxupmt',
#  '#vaccineuniversalism',
#  '#secondcoronavirusvaccinejabs',
#  '#vaccinés',
#  '#vaccinationdriveingurugram',
#  '#lalitpurvaccinealerts',
#  '#jjvaccinejust',
#  '#covid19vaccinesafetymatters',
#  '#vaccinationsforchildren',
#  '#stopthevax',
#  '#vaccinateniagara✌🏽',
#  '#seniorcitizenneedsvaccine',
#  '#covishieldvaccinecorona',
#  '#vaccinecontainer',
#  '#vaccinatiester',
#  '#vax1',
#  '#myfirstvaccinationagainstcovid19',
#  '#getvaccinatedwithwhateverworks',
#  '#vaccinationews',
#  '#vaccineinjuiries',
#  '#novaxmanifestazionicontagi',
#  '#vaccinvies',
#  '#gotovaccine',
#  '#vaccinateeveryindianforindia',
#  '#stasivaccine💉',
#  '#ohiomanorderedjudgecovid19vaccinetwoyearprobation',
#  '#getvaccinatedbeforeyougetcovid19',
#  '#vacccinediplomacy',
#  '#getvaccinatedsc',
#  '#allaboutthevaxx',
#  '#ucpunderminecovidvaccinerollout',
#  '#vaccineforchild',
#  '#getvaccinatedgetvaccinatednowgetvaccinatedasap',
#  '#oneshotcovidvaccine',
#  '#rvax',
#  '#covidvaccinefdaapproved',
#  '#britainvaccinated',
#  '#soignervaccin',
#  '#ukvaccinesuccess',
#  '#selfvaccinating',
#  '#vaxedhospitalized',
#  '#internationalvaccineday',
#  '#vaccinatedatmiramichilodge',
#  '#vaccinepoliticsdelhi',
#  '#heathrowvaxcentre',
#  '#diosynvaxs',
#  '#novaccinenohospital',
#  '#novaccinepassports💜🗳️🇨🇦',
#  '#letsvaccinaton',
#  '#loveyourcommunitygetvaccinated',
#  '#vaccinequ',
#  '#levaccinpaspourmoi',
#  '#vforvaccina',
#  '#massvaccinenowph',
#  '#vaccinactionhttpstcof2l4akdza3',
#  '#vaccinatestudentsसुनने',
#  '#childrensvaccination',
#  '#antivaxterrorists',
#  '#profspasvaccinéspasderentrée',
#  '#hubvaccinaledibenevento',
#  '#vaccinesforpeace',
#  '#freevaccineinwb',
#  '#wakeupamericaregardingvaccines',
#  '#vaccinesarereal',
#  '#largestvaccinedriverobmhgoa',
#  '#bcvaccineqrcode',
#  '#covidvaccimeboosters',
#  '#swedendenmarkpauseusemodernacovid19vaccineyoungeragegroups',
#  '#depopulationvaccines',
#  '#vaccinationhypocrisy',
#  '#vaccinationfreedomday',
#  '#vaccinemythbusters',
#  '#mikedewinevaxpor',
#  '#vaccinationson',
#  '#australianswantpfizervaccine',
#  '#txvaxprogram',
#  '#vaccinationstock',
#  '#happyvaccine',
#  '#vaccineshttpstcoccbkkeylig',
#  '#vaccinationwhy',
#  '#charlieisvaxxed',
#  '#nuovivaccini',
#  '#wymwhileyouwereknockedoutaftervax',
#  '#novaxuno',
#  '#flucelvax',
#  '#rockthevax',
#  '#vaccineshttpstcotinnklw5lc',
#  '#vaccinehow',
#  '#vaccineharish',
#  '#vaccinateklfa',
#  '#indiaforvaccine',
#  '#trumpvaccinesaveslives',
#  '#vaccinobambini',
#  '#fuckingidiotsrefusingtovaccinate',
#  '#asofficialsracetovaccinatecnn',
#  '#antivax👇',
#  '#homegrownvaccines',
#  '#vaxxnowpsu',
#  '#rajasthanvaccination',
#  '#vaxedwaxedandreadytoclimaxe',
#  '#vaxstatusbrag',
#  '#simplemathvaccine100',
#  '#coronalockdownvaccinecoronavaccinetelugunewsmemetelugumemecorona20secondwave2ndwaveprecautionsafety',
#  '#vaccineau',
#  '#vaccinessavelives🚨nomoreconspiracies⛑',
#  '#yorkantivaxxers',
#  '#havethevaccination',
#  '#sheepvaccinated',
#  '#covidfluvaccine',
#  '#vaccinesforthewin💉',
#  '#vaccineliars',
#  '#moroccomakesthevaccine',
#  '#vaccineputmeondisability',
#  '#vaccinebullshittery',
#  '#covid19vaccineequityteam',
#  '#facciamoilvaccino',
#  '#convaccinésfr',
#  '#getthevaccinesoutthere',
#  '#sbrigatevinonvedoloradivaccinarmi',
#  '#vaccineuhttpstcoosypzqzfbu',
#  '#getvaccinatedteamfiji',
#  '#vaccinecurrency',
#  '#donottakethevaxx',
#  '#tumkurvaccinealerts',
#  '#lastmilevaccination',
#  '#tamilnaducovid19vaccination',
#  '#novaccinepassportsif',
#  '#beinformedofdiffcovidvaccines',
#  '#combatantivaccin',
#  '#novaxmi',
#  '#theunvaccinatedmajority✊🏾',
#  '#cowinregistrationforvaccine',
#  '#tmhismyvaxx',
#  '#nomaskiamvaccinated',
#  '#ourvaccineourp',
#  '#notoexperimentalkillercovidvaxxs',
#  '#cantwaittogetmyvaccine',
#  '#vaccinationvinodkannanvfr',
#  '#boostervaccinatie🎢',
#  '#covidvaccinat',
#  '#mortalitévaccination',
#  '#covidvaccinesexposed',
#  '#vaxes',
#  '#vaccineshttpstcofahqzbrwz5',
#  '#jemevaccinejemeprotège',
#  '#waroncovid19anditsvaccine',
#  '#cmdrfvaccine23042021',
#  '#fundaussievaxine',
#  '#postcovidvaccinerunning',
#  '#prounvax',
#  '#uvacovidvaccinestudy',
#  '#vaccinologi',
#  '#vaccinefest',
#  '#vaccinationspass',
#  '#vaccineaccessaddressing',
#  '#vaxxcons',
#  '#covaxinbharatbiotech',
#  '#nothinglikearushedvaccine',
#  '#demsgetvaccinated',
#  '#coronavaccineshe',
#  '#vaxtheoutback',
#  '#vaccinateallanimals',
#  '#vaxa',
#  '#sexuallytransmittedvaccine',
#  '#vaccinateyourselvespeople',
#  '#antivaxer🤢🤢🤢🤮',
#  '#vaccinezlapolice',
#  '#covid19vaccinsmutation484',
#  '#maskvaxflushot',
#  '#covaxinapprovalday',
#  '#heroesgetvaccines',
#  '#totallyvaxxed',
#  '#vaccinatorarmy',
#  '#vaccinated☝️',
#  '#vaccinested',
#  '#longlinesforvaccine',
#  '#vaccinatedplus',
#  '#vaccines4vulnerable',
#  '#largestvaccinationdrive4wuhanvirus',
#  '#vaccineforghaziabad',
#  '#getpeelvaccinated',
#  '#nonvacccines',
#  '#justicebyvaccine',
#  '#covidisairbornevaccinequity',
#  '#vaccinationcant',
#  '#vaccineemergency',
#  '#vaccinategitmo',
#  '#vaccinatjournalist',
#  '#covidvaccinehttpstcolcezuzl6r7',
#  '#vaccinelines',
#  '#shametheunvaccinated',
#  '#vaccinatedsuperhero',
#  '#antivaxxquacks',
#  '#vaccinateeveryone️',
#  '#wayofvaccintionsocialdistancing',
#  '#seattlevaccine',
#  '#photowithvaccine',
#  '#novavaxgang',
#  '#rojavavaccinepipeline',
#  '#vaxdeterioration',
#  '#experimentalvaccin',
#  '#srilankacoronavaccination',
#  '#stopthepoisonvaccine',
#  '#doortodoorvaccinationnow',
#  '#nepalvaccinationscam',
#  '#staysafegetvaxxed',
#  '#nomoreforcedvax',
#  '#savethemoutainsresignkenneysupporteachersnoticutsvaccinesinarmssave',
#  '#isupportindianvaccine',
#  '#nomasksnovaccine',
#  '#vaccinatethevalley',
#  '#chhattisgarhvaccination',
#  '#radiologybusinesshttpswwwradiologybusinesscomtopicsleadershipworkforcersna2021chicagorequirecovid19vaccinationmasks',
#  '#mpvaccinationabhiyan',
#  '#vaccinationdriveit',
#  '#lasvegasvaccinatio',
#  '#modernavaccinebooster',
#  '#researchvaxxingredients',
#  '#vaccinewebinar',
#  '#biggestvaccinedrive',
#  '#getvaxxedbeforeitstoolate',
#  '#getvaccinatedsoo',
#  '#azaadkashmirmienvaccinekab',
#  '#sivaccinovolontario',
#  '#ignorateinovax',
#  '#unvaxxedfools',
#  '#banvaccinepassorts',
#  '#vaccineforzim',
#  '#unvaccinatedkaren',
#  '#getthefuckingvaccination',
#  '#vaccination=gtcarnetb',
#  '#intranasalcoronavirusvaccine',
#  '#vaccinedebate',
#  '#vacccinatieschade',
#  '#huganunvaccinated',
#  '#vaccinewillbefree',
#  '#covidvaccinationcentreshyd',
#  '#furtovaccini',
#  '#modikavaccinejum',
#  '#httpswwwredvoicemediacom202110pandemicofthevaccinatedgeneratingmutantchinesevirusstrainsmoreinfectedthanunvaccinated',
#  '#vaccineswork👈',
#  '#covdvaccineisdelta',
#  '#britishvaccineracism',
#  '#vaccinateteachersplease',
#  '#cvsvaccinenegilence',
#  '#bachevaccinatedha',
#  '#unvaccinatedpeoplearescary',
#  '#vaccinesharingprogramme',
#  '#nationalvaccinationopera',
#  '#vaccines😟',
#  '#biggestvaccinationdrive',
#  '#jnjvaccinates',
#  '#getthehpvvaxnow',
#  '#vaccinatevialfosso',
#  '#againstvaccinepassports',
#  '#toxiccoronavaccinespartofpharmagame',
#  '#trichyletsvaccinate',
#  '#vaxxedandstilldoublemasked',
#  '#wastedvaccines',
#  '#getvaccinegethard',
#  '#fmvaccinate',
#  '#vaccinetests',
#  '#apartheidvaccine',
#  '#meraboothvaccineyukt',
#  '#vaccineerjongeren',
#  '#vaccinationsand',
#  '#vaccinatedrally',
#  '#cowdungantivaxxer',
#  '#covidvaccine🔴httpstcoyinc1igrhw',
#  '#coronarvirusvaccine',
#  '#wheresthevaccinations',
#  '#novaccinenojob',
#  '#getvaccinatedhealingstartshere',
#  '#pledgedtocovercovid19vaccinationcost',
#  '#vaccinatereporters',
#  '#vaccinecardcase',
#  '#vaxgreen',
#  '#getthevaccineassholes',
#  '#vaccinoidolatria',
#  '#mitchmcconnellvaccine',
#  '#maskupgetvaxed',
#  '#spreadingcovidwithvaccine',
#  '#vaccinatenh',
#  '#compulsoryvaxforworkvisa',
#  '#ottawacovidvaccineages',
#  '#vaxvezria',
#  '#wearadamnmask😷vaccineswork',
#  '#getvaccinatedorgetfucked',
#  '#vaccinatmums',
#  '#hiddenvaccine',
#  '#vaccine🏅',
#  '#vaccinefofnewyork',
#  '#covidvaccinazispuitje',
#  '#worldaidsvaccineawarness',
#  '#getvaccs',
#  '#phuckantivaxxers',
#  '#covidvaccinepandamic',
#  '#loteriavaccinatilor',
#  '#vaccinationbulletin',
#  '#scotlandthevaccinated',
#  '#fullyvaccinatedmeansfreedom',
#  '#climatevax',
#  '#allvaccinesarebetterthancovid',
#  '#vaccine=',
#  '#democratantivaxxers',
#  '#sovranitàvaccinale',
#  '#equitablevaccinerollout',
#  '#antivaxxerterrorists',
#  '#vaccinecover',
#  '#drongovaccinealert',
#  '#valueofvaccinescampaign',
#  '#southafricasaysastrazenecascovid19vaccineisnotef',
#  '#unvaxxedscapegoats',
#  '#trichyvaccineupdates',
#  '#vaxupcats',
#  '#vaccinemandateskill💀fjb🤬',
#  '#shorttricksvaccine',
#  '#foxgopvaccinelies',
#  '#bidendeltavaccine',
#  '#vaxmaskanddistance',
#  '#bungledvaccination',
#  '#modernavaccineboostershots',
#  '#covid19vaccinen',
#  '#punjabvaccineshortage',
#  '#antivaccerstakenote',
#  '#togetthevax',
#  '#vaccinesareabigthing',
#  '#covid19vaccineexperments',
#  '#koreacovidvaccination',
#  '#getvaccinated😊',
#  '#undervaccinationus',
#  '#valorevaccinazione',
#  '#vaccinationestlasolution',
#  '#laprotestadeivaccinati',
#  '#vaccinevscovid',
#  '#stopvaccinpassport',
#  '#vaccinationinparliamentfirst',
#  '#bikevax',
#  '#novaccinecertificates',
#  '#upcovidvaccine',
#  '#vaccineg4kids',
#  '#goteamvax',
#  '#covidvaccije',
#  '#vaccinationcovi',
#  '#covidvacciné',
#  '#ihavetakenthevaccine',
#  '#vaxornottovax',
#  '#chiproyisvaccinated',
#  '#massvaxsite',
#  '#vaccinatedwear',
#  '#vax21',
#  '#deadaftervax',
#  '#standupagainstvaccinepassports',
#  '#vaccinesparticularly',
#  '#l0ckd0wnthevacclnatedsuperspreaders0fdeitavarlant',
#  '#fullyvaccinated😁have',
#  '#covaxxes',
#  '#coronavaccineoffers',
#  '#vaxreports',
#  '#fakevaccine',
#  '#vaccinadoubledose',
#  '#covidvaccinegreenecounty',
#  '#covid19vaccinationtossers',
#  '#alleligiblegetvaccinated',
#  '#eurovaccinemadness',
#  '#needvaccinated',
#  '#hotvax',
#  '#antivaxxersaredrawntotheconservativemovementlikefliestoadeadcamelinthesahara',
#  '#amitabhbachchancovid19vaccine',
#  '#covidvaccine☠️is',
#  '#vaccinestandard',
#  '#gitmovaccine',
#  '#vaccinatezimbabwe',
#  '#zikavaccines',
#  '#vaxupbeardown',
#  '#vaccinefaucimask',
#  '#mpvaccinationmahaabhiyan2',
#  '#jemeferaivacciné',
#  '#coronavaccinationcamps',
#  '#vaccinstuentp',
#  '#worldhealthjohnsonampjohnsonpandemicpfizerusavaccinesvirus',
#  '#vaxtoyou',
#  '#gladimvaxed',
#  '#worstvaccinedistributionstate',
#  '#pointlessvaxx',
#  '#novax🤔',
#  '#vaccinationforallinindia',
#  '#stopc19vaccine',
#  '#tawiwanvaccine',
#  '#pregnantladiesvaccineguideline',
#  '#vaccineeqy',
#  '#giveindiathevaccine',
#  '#allvirtualtilvaccinated',
#  '#vaccihttpstcoavmnv0doev',
#  '#tattooyourvaccinationpassportnumber',
#  '#vaccintegencovid19',
#  '#chinafakevax',
#  '#vaxantarctica',
#  '#vaccinatedincluding',
#  '#lesvaccinscamarche',
#  '#vaccinerenisverweren',
#  '#gapbetweentwocovid19vaccineshots',
#  '#coronavaccinationstart',
#  '#vaccinatedinchrist',
#  '#vaccinateniaga',
#  '#euvaccineprocurement',
#  '#unvaccinatedstayawayfromhospitals',
#  '#vaccinationingbnagar',
#  '#armymatchbtsvaxx',
#  '#cevaccinrendfou',
#  '#ifonlytherewasavaccine',
#  '#vaccinessavesyourlifeandothers',
#  '#crazyantivaxer',
#  '#vaccineverse',
#  '#soignantsnonvaxvirés',
#  '#vaccinateventilatemask',
#  '#lockdowandvaccinate',
#  '#vaccineland2021',
#  '#novaccinonoparty',
#  '#covaxiin',
#  '#nivaccinniqrcodenipass',
#  '#trumpvaccinationdrive',
#  '#consideredfullyvaccinated',
#  '#vaxddoesntmeansafe',
#  '#vaxdaresuperspreaders',
#  '#vaccinationcampnellai',
#  '#secretvaccinations',
#  '#truthaboutloveantivax',
#  '#gettestedandvaxed',
#  '#vaccinecoecion',
#  '#vaccine4grandma',
#  '#vaccinated~one',
#  '#paunocudosantivax',
#  '#vaccinatedwitch',
#  '#waiting4vaccination',
#  '#ourvaccineourpridesri',
#  '#vaxd',
#  '#vaxyourselfbeforeyouwreckyourself',
#  '#metronewslkcovid19vaccine',
#  '#goawaycovid100vaccinatedcmalifetshirt',
#  '#vaccinetrustbuilding',
#  '#donttakepoisonvaccine',
#  '#donottaketheirvaccine',
#  '#vaccinflytox',
#  '#gettinganyvaccineisbetterthangettingcovid',
#  '#imvaccinated💉all',
#  '#preclinicalvaccine',
#  '#thủtướngđứchốithúcngườidântiêmvaccinephòngcovid19',
#  '#prenotazionivaccini',
#  '#verplichtvaccinere',
#  '#novaccinenopandemict',
#  '#covid19vaccination😷',
#  '#childvaccinecomesoon',
#  '#forcovid19vaccination',
#  '#thegorillavaccine',
#  '#vaccinationfreezers',
#  '#covidvaccine4lamarj',
#  '#usvaccinerate',
#  '#hosurofficial|coronasecondwave|covid19|tnlockdown2021|covaxin|lockdown2021|lockdownextension',
#  '#innovaccin',
#  '#fckyourvaccine',
#  '#westbengalcovid19vaccine',
#  '#hyderabadbiggestvaccunation',
#  '#vaccinewontsaveyou',
#  '#vaxfreeholidays',
#  '#vaccinehogging',
#  '#vaccinateround1',
#  '#unvaxxe',
#  '#covidvaccinerawmaterial',
#  '#lookingforreasonstovaccinatenottoturnaway',
#  '#stopmandatorycovidvaccine',
#  '#vaccineforlactatingwomen',
#  '#vaccinebreakthroughinfection',
#  '#lnpvaccinationrollout',
#  '#chinafakevaccinekills',
#  '#anticovidvaxxer',
#  '#covidvaccinesideef',
#  '#scottishstudyvaccines',
#  '#vaccineapartheid👇',
#  '#vaccineinternationalism',
#  '#antivaxxerscantdomath',
#  '#tousnonvaccinés',
#  '#vaccinevow',
#  '#vaxrewards',
#  '#vaccine🇨🇴',
#  '#opentheborderforvaccinated',
#  '#covidvaccinationpediatrics￼',
#  '#vaccinestooslow',
#  '#vaccimbéciles',
#  '#thevaccineconqueringcovid',
#  '#covidvaccineforall',
#  '#astravaccinr',
#  '#vaccineden',
#  '#autrevaccin',
#  '#vaxprochoice',
#  '#mulundvaccineupdate',
#  '#vaccinesstillwork',
#  '#nofreevaccinegame',
#  '#universalvax',
#  '#piegevaxinal',
#  '#vaccinationsforasthmatics',
#  '#utahvaccine',
#  '#covidvaccinealberta',
#  '#promotevaccinesnotlockdowns',
#  '#ookgevaccineerdenbesmetten',
#  '#getyourdamnvaxx',
#  '#vaccinesworkagainstdelta',
#  '#vaccineboostersforever',
#  '#vaccinelatestnews',
#  '#friendswhogetvaccinatedtogetherstaytog',
#  '#vaccinesfertility',
#  '#certificateofvaccinationidai',
#  '#antivaccinepassp',
#  '#iam50yrsoldandiamvaccinated',
#  '#vaccinaziun',
#  '#vaccinsfoireux',
#  '#nepalneedsoxygennepalneedsvaccine',
#  '#vaccineshttpstcoaqgqgica6u',
#  '#vaccine⚕️',
#  '#vaccines⬇️⬇️⬇️',
#  '#cancelexamssavestudentsvaccination',
#  '#borisjohnsonvaccinations',
#  '#vaccinationmess',
#  '#covidvaccineformula',
#  '#noidnouseofvaccinationcard',
#  '#israelivaccinationapartaheid',
#  '#oproepvaccinatie',
#  '#tiêmvaccinepfizer',
#  '#covaxinupdates',
#  '#vaccinationutsav',
#  '#vaccinateviebasta❗❗❗',
#  '#passonthevaxx',
#  '#unvaccinatedlivesmatter',
#  '#aninivaccination',
#  '#pleasedontsendmeanysoddingantivaxtweets',
#  '#fkthevaxx',
#  '#freevaccinationforbihar',
#  '#neovaccine',
#  '#dosomethingvaccinated',
#  '#ongevaccineerdenwereldwijd',
#  '#dontwaittovaccinate',
#  '#ilpiemontenonvaccina',
#  '#fakevaccinemumbai',
#  '#emailvaccination',
#  '#vaccinerat',
#  '#jandjvaccinerecall',
#  '#sivaccino',
#  '#vaccones',
#  '#getvaccinationinindia',
#  '#vaccinetheinsidestory',
#  '#novaxfuck',
#  '#distributionofvaccinecoupons',
#  '#mobilevaccinator',
#  '#novaxdjocovic',
#  '#takethedamnvaccine',
#  '#bidenvaccinecrisis',
#  '#vaccineonlysolution',
#  '#halfvaccinatedpanboy',
#  '#vaccinatenhhighered',
#  '#vaccinsgratuitspourtous',
#  '#maskuntilvaccination',
#  '#whichvaccineisbetter',
#  '#kidsdontneedvaccine',
#  '#yourvaccinatedsowhocares',
#  '#vaccinateloudoun',
#  '#vaccinpourtous',
#  '#vax511',
#  '#mybmcvaccinationupda',
#  '#largestcovid19vaccinationdrive',
#  '#vaccinationpause',
#  '#noneedvacc',
#  '#coronavaccinationinpunjab|',
#  '#symptomsaftervaccination',
#  '#ovaccinerade',
#  '#talkcoronavaccines',
#  '#wtfisinthevaccine',
#  '#indiausedfakevaccine',
#  '#pentagonvaccine',
#  '#euvaccinedisaster',
#  '#expertwarnsunvaccinatedamericansarestillathighriskforcovid19cnn',
#  '#antivaxxercoviddeniers',
#  '#coronavaccine|',
#  '#covaxinapprovalsoon',
#  '#testisolatevaccinate',
#  '#backofthelineforantivaxxers',
#  '#vaccineedition',
#  '#unvaxxedkillingeconomy',
#  '#anitivaxx',
#  '#betterdayswhenwevaccinate',
#  '#vaccinationhttpstcogm3mge4oti',
#  '#issuevaccinepassports',
#  '#annointedismyvaccine',
#  '#didivaccinechorikajababdo',
#  '#canusdeplorableunvaccinatedstillatleasthavefridays',
#  '#vaxmandateswork',
#  '#freecovidvaccinationshots',
#  '#rdvvaccin',
#  '#getvaccinatedwv',
#  '#covaxin1stdose✅',
#  '#vaccinationtrumpism',
#  '#alaskavax',
#  '#herpesvaccine',
#  '#notovaccineforme',
#  '#removevaxmandate',
#  '#postvaccineworkplace',
#  '#voomaweekendvaccination',
#  '#vaxdistribution',
#  '#executionbyvaccination',
#  '#vaccination💉proof',
#  '#savelivesbygettingvaccinated',
#  '#mpvaccinationmahaabhiyan2running',
#  '#googleemployeesvaccination',
#  '#quépasóconcovax',
#  '#vaccinemandatesdestroylives',
#  '#vaccinesintimegtgtgt',
#  '#vaccinerelatedcriminalcases',
#  '#novaccinesnowork',
#  '#novaxinpandemia',
#  '#antivaxxersverdienengeenprijzen',
#  '#vaccinazionemorbillo',
#  '#covid19vaccinetulsa',
#  '#antivaxxerswhether',
#  '#geenvaccinatievoorgezondemensen',
#  '#novaccinenoadmittance',
#  '#vaccinebeast',
#  '#notvaccinated👍🏽',
#  '#dontbeanantivaxxer',
#  '#vaccinleveringen',
#  '#covidvaccaine',
#  '#tmcvaccinechor',
#  '#indiavaccineban',
#  '#vaccinedeathnevereverondeathcertificate',
#  '#vaccinatieweigeraar',
#  '#vaccinecerificate',
#  '#vaccinecootiesforthewin',
#  '#covidvaccineisneeded',
#  '#nosmvaccinerollout',
#  '#covidvaccinecentersinamravati',
#  '#vaccinespring',
#  '#howsafearethesevaccines',
#  '#genebasedvaccines',
#  '#clovervaccine',
#  '#getmethevaccine',
#  '#doublevaxdaddy',
#  '#vaccinatetosurvive',
#  '#antivaxtwitterblase',
#  '#vaccinatedd💉💉',
#  '#vaccinepaspoort',
#  '#vaccinemandateisamust',
#  '#bewarethevaxed',
#  '#vaccinationequalsvarients',
#  '#vaccinationistheway',
#  '#vaccini👏👏👏👏👏',
#  '#vaccinationrecipients',
#  '#gotbacksgetvaxxed',
#  '#donotusethatuntestedunprovenvaccinejunk',
#  '#cvidvaccine',
#  '#vaccineisnovotetobjp',
#  '#noiwouldtgogetthevaccine',
#  '#lifeaftervaccines',
#  '#modernavaccinefailure',
#  '#ottawavaccinespharmacies',
#  '#getfullyvaccinatednow',
#  '#fullyvaccinated✌️indiafightscovid19',
#  '#china039scovid19vaccinationdriveisabouttohitthe2billionmarkcnn',
#  '#vaccine\u200b\u200b',
#  '#eivaccin',
#  '#notokillervax',
#  '#vaccinessavelives💉🦠👊',
#  '#corona|vaccination|nashikdivision|chiefminister|uddhavthackeray|divisionalcommissioner|collector',
#  '#vaccines😭',
#  '#ccpvirusfaucicovidvaccine',
#  '#nomandatedvax',
#  '#vaccinationro',
#  '#dailyvaccinations',
#  '#noempathyforantivaxxers',
#  '#panthersgetvaxxed',
#  '#getyourvaxonnyc',
#  '#civoglionopiuvaccini',
#  '#vaccinaterich',
#  '#supportedcovidvaccine',
#  '#hepatitisvaccinaties',
#  '#vaccination💉💉',
#  '#vaccinatetosavezimbabwe',
#  '#auntyvaxx',
#  '#vaccineneedmoredata',
#  '#pfizerbiontvaccine',
#  '#vaccinedoesnotstoptransmission',
#  '#noprofitonvaccine',
#  '#baretagvaccinen',
#  '#mpvaccinedoses',
#  '#yogivaccinedo',
#  '#sahivaccine',
#  '#vaccinationagainstcoronacrossed13crore',
#  '#vaccinatetargetsubjects',
#  '#getvaccinatedwhenyoucan',
#  '#stopforcedvacci',
#  '#chiarezzasuivaccini',
#  '#usvaccinecertificate',
#  '#theunvaccinatedareadangertoall',
#  '#antivaxtwits',
#  '#murderbyvaccination',
#  '#covidvaccinesauthorizedintheeu',
#  '#sideeffectsofvaccination',
#  '#vaccintwijfelaars',
#  '#eerstevaccinatieinbuitenland',
#  '#takensecondvaccine',
#  '#letvaccinatedpeoplethrough',
#  '#vaccineround2',
#  '#dontbeanassholegetyourvaxhole',
#  '#vaccinatocovid19',
#  '#vaccinaccidents',
#  '#myoncologistwouldvaccinatemetodayifshecould',
#  '#vaxtransjt',
#  '#attackonvaccineteam',
#  '#coronavaccinationcase',
#  '#waitingforthevaccine',
#  '#equityforvaccines',
#  '#stopvaccineren',
#  '#vaccineobits',
#  '#vaccinecovishield',
#  '#makevaccinecomplusary',
#  '#covidcausesimpotencegetvaxxed',
#  '#vaccinatedandstillmaskedup',
#  '#shouldimixvaccines',
#  '#vaxafghanistan',
#  '#anythingbutthevax',
#  '#letsgetvaccinated😷',
#  '#vaccineantivax',
#  '#vaccinepimping',
#  '#covidvaccination2021',
#  '#nejtillvacci',
#  '#vaccinesforspecialkids',
#  '#vaccinated=',
#  '#nationalvaccinatioday',
#  '#vaxbrats',
#  '#novaccinepadsports',
#  '#theyrenotvaccines',
#  '#nzvaccinebus',
#  '#partiellementvaccinés',
#  '#coronavaccinedevelopers',
#  '#gacovidvaccines',
#  '#covidvaccineswithstates',
#  '#indianeedvaccines',
#  '#novaccinenoofflineexams',
#  '#vaccinegstfree',
#  '#getjabbedpaycutclubsdockwagesunvaccinatedplayers',
#  '#vaccinatemyballz',
#  '#getmartyvaccineparty',
#  '#yesvaccinatedcangetit',
#  '#vaccinojohnsonampampjohnson',
#  '#vaxsongs',
#  '#indianstatesneedvaccine',
#  '#covaxinaroundtheworld',
#  '#certificatvaccinal',
#  '#stopforcevaccination',
#  '#vaccineequility',
#  '#covid19vaccine🚨9999',
#  '#myvaccinestorynt',
#  '#covaxwhotripswavier',
#  '#covid19joebidenvaccine',
#  '#novaccinepasses',
#  '#vaccinemandats',
#  '#ikkevaccinerede',
#  '#unmaskedunvaxedunafraid',
#  '#mygodwouldvaxx',
#  '#vaccinerolloutconnect',
#  '#globalvaccinepassportsystem',
#  '#covidvaccinecentersinosfatehabaad',
#  '#covaxinforphase3trials',
#  '#nuvaxovidimpfstoff',
#  '#novaccineno1012exam',
#  '#vaccine4safety',
#  '#vaccinetruckcouldntbelieveiteither',
#  '#antimaskervaxxer',
#  '#leakyvaccin',
#  '#covidvaccs',
#  '#httpswwwcbsnewscomnewsindiacovidcrisisdeathsvaccineoxygen',
#  '#seniorscovidvaccine',
#  '#vaccinatiepaspoortgeleboekje',
#  '#virtaluntilvaccinated',
#  '#tweetenalseenantivaxxer',
#  '#anotheronebitesthedustafter3rdcovidvax',
#  '#nocoronavaccinationcertificate',
#  '#vaccinetobsnlemployees',
#  '#novaxexemption',
#  '#vaccinatesweatshirt',
#  '#irathernotbevaccinated',
#  '#vaxrestofworldfirst',
#  '#moronswhodontgetvaccinated',
#  '#nashik|nandurbar|corona|coronavaccination',
#  '#vaccinationonholidays',
#  '#vaccinetracing',
#  '#vaccinesformalaysia',
#  '#spikevaccinethrombosis',
#  '#coronavaccinethiruvananathapuramkerala',
#  '#southparqvaccinationspe',
#  '#novaccinepassportforme',
#  '#freevaccinationfora',
#  '#noalfintovaccino',
#  '#vaccinesareviolence',
#  '#akolavaccination',
#  '#vaccupbulldogs',
#  '#gatorsvacc',
#  '#vaccinationcenterବନ୍ଦହୋଇଯାଇଥିବାରୁଯନ୍ତ୍ରଣାଭୋଗୁଛନ୍ତିଲୋକେ',
#  '#hitthevaccinationstation',
#  '#businessvaccinal',
#  '#vaccination2021',
#  '#genocidebyvaccine',
#  '#roundupthevaxxed',
#  '#hiddenvaccineranch',
#  '#fakevaxx💉',
#  '#triplevaxspreaders',
#  '#covid19vaccination🙏🏽',
#  '#httpswwwwsbtvcomnewslocalatlantacdcdirectordefendsreversingmaskguidelinesfullyvaccinatedamericansaof276rqare2zhytiujxypwfoa',
#  '#healthinsurancevaccinemandate',
#  '#vaxrttheworld',
#  '#vaccinemythbuster',
#  '#speakupforfreeuniversalvacci',
#  '#nebuďantivaxer',
#  '#scamvaccine',
#  '#ongevaccinnerd',
#  '#indiavaccinationwho',
#  '#vaccinestudyresponseimpairedimmunesystemspatients',
#  '#fabricedivizioavocatcnewsmorandinipolitiqueagnesevrenlrdebatvaccinisraelcovidvirus',
#  '#vaccindoses',
#  '#whereisthevaccineanita',
#  '#vaccineshortage',
#  '#justwaitandvaccinate',
#  '#albertacovid19vaccine',
#  '#buildthenationwithvaccination',
#  '#vaxupalaska',
#  '#vaccinatehttpstco0p9vbxcfsc',
#  '#vaxforlivec',
#  '#vaccinatedht',
#  '#navaccinepassport',
#  '#approvethenovavax',
#  '#dingosduvaccin',
#  '#antivaxxersarenasty',
#  '#infectionsposvaccinales',
#  '#getvaccinatedidiot',
#  '#nomandatorychildvaccination',
#  '#pfizervaccinepfizerbiontechpfizer',
#  '#trustyourvaccineमुझे',
#  '#nswvaccinations',
#  '#skoreabritainvaccineswap',
#  '#italiaaafermatellvaccinoanticovid',
#  '#dateofvax',
#  '#notoforcedvaccinatiom',
#  '#bankerneedvaccinate',
#  '#bjpkaavaccine',
#  '#vaccinistibugggiardi',
#  '#takethevaccinetothem',
#  '#vaccinessavesperm',
#  '#greenpassvaccinepassports',
#  '#covidvaccinations💉',
#  '#choosevaccinations',
#  '#endvaxmandate',
#  '#militaryvaccinators',
#  '#readyforthirdphasevaccination',
#  '#deathovervaxx',
#  '#novaccinebaby',
#  '#astrazenecavaccinedenmark',
#  '#japanlackofvaccines',
#  '#nflshouldrequirevaccination',
#  '#vaccinesevidemyre',
#  '#vaccinekarnataka',
#  '#vaxymorons',
#  '#vaccinatelao',
#  '#arrestantivaxxers',
#  '#freecoronavaccin',
#  '#coronavirusvaccinecertificates',
#  '#covidvaccinecovid',
#  '#vaccinatemejt',
#  '#vaccinemandateurges',
#  '#vaxnotfdaapproved',
#  '#thecovid19vaccineontrial',
#  '#boycottvaccinerefusers',
#  '#seafarersvaccinationonlywayout',
#  '#pregnantaftervaccination',
#  '#vaccelerateonderzoeken',
#  '#vaccinationsforvacations',
#  '#vaccineadverse',
#  '#forcedvaxbullyscum',
#  '#vaccinecoercionlockdown',
#  '#vaccinerecipes',
#  '#covidvaccinebothdosesgive98percentprotection',
#  '#donationforvaccine',
#  '#covax👀',
#  '#produzionevaccini',
#  '#coronavaccinenepal',
#  '#petitionvaccine',
#  '#laggedvaccinationinjapan',
#  '#vaccinesthecrisis',
#  '#postvaccinationdeaths',
#  '#indianrailwayscoronavaccination',
#  '#vaxmenot',
#  '#vaccinestrategi',
#  '#vaxenfant',
#  '#perplexedvax',
#  '#getvaxxedtn',
#  '#vaccineforsouthafrica🤔😲🥴',
#  '#covid19vaccinesk',
#  '#voronavaccineapp',
#  '#covid19vaccinesng',
#  '#screen4vaccine',
#  '#vaccinegang💪🏾💉',
#  '#youcanstillgetcovidafterbeingvaccinated',
#  '#ovaccinatiomorti',
#  '#vaccineincreasing',
#  '#covidvacccinevivekbndracoronamadeinindiaatmnirbhrbhartoxygenconcentratoroxygenhelpbreathoxygenconcentrator',
#  '#vaccinationbuddies',
#  '#vaccinanel',
#  '#vaccineकाformula',
#  '#antivaxxerswilldie',
#  '#covidvaccineu',
#  '#vaccinatecolorado',
#  '#blameantivaxxers',
#  '#guerirsansvaccin',
#  '#hurricaneskilltheunvaccinated',
#  '#vaccinoprudent',
#  '#vaccinepassportsforfreedom',
#  '#getvaxxedrighgnow',
#  '#solidaritywithunvaxed',
#  '#keeaisreadyforthevaccine',
#  '#vaccineobsessedsyndrome',
#  '#vaxguy',
#  '#vollediggevaxineerd',
#  '#nowsaferthanbeingvaccinated',
#  '#youareantivax',
#  '#findkidsavaccine',
#  '#dangerousvaccine',
#  '#vaccinatemorepeople',
#  '#pleaseconfessmebeforevaccine',
#  '#jaicovidvaccine',
#  '#unvaxedlockdown',
#  '#prfizervaccine',
#  '#vaccinationrap',
#  '#stopmandateingvaccination',
#  ...}
