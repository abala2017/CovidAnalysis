# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
df = pd.read_csv("peakhash.csv")

# %%
def cleanTags(tag):
    tag = tag.replace("#","")
    tag = tag.lower()
    return tag

# %%
df["Hastag"] = df["Hastag"].apply(cleanTags)

# %%
badTags = ["india", "pune", "uk", "dehi", "australia"]
df = df[~df["Hastag"].isin(badTags)]

# %%
df['Date'] = pd.to_datetime(df['Date Created'])

# %%
numtags = 10
tags = list(dict(df["Hastag"].value_counts()[:numtags]).keys())

# %%
#byMonth and chart the 5
tagCounts = {}
for tag in tags:
    monthCount = []
    for i in range(12):
        monthCount.append(len(df[(df["Hastag"] == tag) & (df["Date"].dt.month == i+1)]))
    tagCounts[tag] = monthCount

# %%
tags
# Out:
# ['covid19',
#  'covid',
#  'coronavirus',
#  'whatshappeninginmyanmar',
#  'vaccine',
#  'lockdown',
#  'pandemic',
#  'corona',
#  'wearamask',
#  'breaking']

# %%
timeline = pd.read_csv('covidTimeline.csv')
timeline['date'] = pd.to_datetime(timeline['date']).dt.date

# %%
y = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep" , "Oct", "Nov", "Dec"]
for tag in tags:
    plt.plot(tagCounts[tag], label = tag)
plt.ylabel("Count")
plt.xlabel("Month")
#plt.figure(figsize=(8, 6), dpi=80)
plt.legend()
plt.show()

# %%
covidData = pd.read_csv("owid-covid-data.csv")
covidData = covidData[(covidData['location'] == 'United States') & (covidData['date'].str.contains('2021'))]
covidData['date'] = pd.to_datetime(covidData['date']).apply(lambda day: day.date())
figure(figsize=(15, 6), dpi=80)
plt.plot(covidData['date'], covidData['new_cases'])

for i, row in timeline.iterrows():
    covidVal = min(list(covidData['date']), key=lambda x: abs(x - row['date']))
    plt.text(row['date'], covidVal, row['event'])

plt.show()

# %%
figure(figsize=(15, 6), dpi=80)
plt.plot(covidData['date'], covidData['new_cases'])
plt.show()

# %%
timeline
# Out:
#           date                                              event  \
# 0   2021-01-29         Johnson & Johnson's Covid Vaccine released
# 1   2021-01-30  One year since WHO declared public health emer...
# 2   2021-01-04                 Alpha variant shows up in New York
# 3   2021-03-02              Texas and Mississippi annouce opening
# 4   2021-03-11  Biden announces plans to make vaccines availab...
# 5   2021-05-13  CDC says that fully vaccinated people don't ne...
# 6   2021-07-07    Delta Variant becomes the most prominent strain
# 7   2021-12-01              Omicron shows up in the United states
# 8   2021-09-10  Biden mandates Covid-19 vaccines for federal w...
# 9   2021-04-19  Vaccine eligibility opens to all adults in the US
# 10  2021-10-19                        FDA autorizes booster shots
# 11  2021-12-28                         Highest daily cases number
#
#                                                  link
# 0   https://www.devex.com/organizations/johnson-jo...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
